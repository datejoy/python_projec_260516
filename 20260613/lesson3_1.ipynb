# %%
import pandas as pd

df = pd.read_csv("考試分數_3年6班.csv")
# print(df.head())

stu = df[df["學生姓名"] == "趙冠宇"]
# print(df["學生姓名"])
# print(df["學生姓名"] == "趙冠宇")
# print(stu)

# print(stu.iloc[0])

scores = stu.iloc[0][["語文", "數學", "英語", "物理", "化學"]]
scores.index
print(scores.values)
# Out:
# [np.int64(85) np.int64(82) np.int64(88) np.int64(84) np.int64(86)]
