# %% [markdown]
# #更新套件:
# - uv sync --upgrade ()
#
# #Pandas:
# - Series
# - DataFrame (表格資料):
#   資料分析最常用
#
# #主執行檔:
# - 有main()的為主執行檔(給python執行的)
#
# #自訂module:
# - 非主執行檔
#
# #介面(最常用):
# - 應用程式 (ex:word)
# - 網頁 (ex:365網頁版)
#
# ##個人用的應用程式介面
# - tkinter (內建應用程式介面)
