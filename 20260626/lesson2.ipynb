# %%
import numpy as np
import matplotlib.pyplot as plt

labels = ['nokia', 'sony', 'apple', 'lumia']
values = [20, 30, 45, 10]
colors = ['yellow', 'blue', 'red', 'green']

fig = plt.figure()
axes1 = fig.add_subplot()
axes1.pie(values,
         labels=labels,
         colors=colors,
         explode=[0.3, 0, 0, 0],    # 裂開
         shadow=True,               # 影子
         autopct="%2.2f%%",         # 標註百分比
         startangle=180)            # 旋轉
plt.show()

# %%
# 步驟 1:匯入 matplotlib.pyplot,取別名為 plt
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

# 步驟 2:建立飲料名稱的串列(奶茶、紅茶、綠茶、咖啡)
labels = ["奶茶", "紅茶", "綠茶", "咖啡"]

# 步驟 3:建立各飲料銷售杯數的串列(50、25、35、40)
values = [50, 25, 35, 40]

# 步驟 4:建立四種顏色的串列
colors = ["#dfbf8b", "#c54b49", "#62a269", "#6f4f2f"]

# 步驟 5:建立 explode 串列,讓奶茶那一塊突出 0.2,其餘為 0
explodes = [0.2, 0, 0, 0]

# 步驟 6:建立 figure
fig = plt.figure()

# 步驟 7:用 add_subplot() 建立 axes
axes = fig.add_subplot(1,1,1)

# 步驟 8:呼叫 axes.pie(),傳入杯數,並設定 labels、colors、explode、
#         startangle=90、shadow=True、autopct='%1.1f%%'
font = FontProperties(fname="C:\Windows\Fonts\msjh.ttc")

axes.pie(values,
         labels=labels,
         colors=colors,
         explode=explodes,
         shadow=True,
         autopct="%1.1f%%",
         startangle=90,
         textprops={'fontproperties': font}
         )


# 步驟 9:用 plt.show() 顯示圖表
plt.show()
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\W'
# <>:25: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\joy_lee\AppData\Local\Temp\ipykernel_55064\2822570872.py:25: SyntaxWarning: invalid escape sequence '\W'
#   font = FontProperties(fname="C:\Windows\Fonts\msjh.ttc")
