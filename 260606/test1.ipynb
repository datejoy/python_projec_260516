# %% [markdown]
# # 全域變數
# - 在python中只要不是nameSpace底下的變數，皆為文件變數，整份文件都可以用
#
# # 區域變數
# - python的命名空間定義：function中的城市區塊即為命名空間
# - 使用範圍: function中
#
# # pip 套件管理應用程式(youbike api 範例)
# - 可放外部套件
# - 可灌在虛擬環境裡面
# - venv 中也有pip (因虛擬環境適用UV建的，所以要用uv add 套件名稱)
#
# # 實體方法
# - ex: json(**kwargs: Any) → Any:
# 「**」代表沒有限定數量的引述名稱呼叫
